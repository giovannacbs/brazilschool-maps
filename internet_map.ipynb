# %%
import pandas as pd
import geopandas as gpd
import xyzservices
import geojson
import numpy as np
# !pip install mapclassify
import matplotlib.pyplot as plt
# Out:
# Requirement already satisfied: mapclassify in /opt/anaconda3/lib/python3.11/site-packages (2.8.0)
# Requirement already satisfied: networkx>=2.7 in /opt/anaconda3/lib/python3.11/site-packages (from mapclassify) (3.1)
# Requirement already satisfied: numpy>=1.23 in /opt/anaconda3/lib/python3.11/site-packages (from mapclassify) (1.26.4)
# Requirement already satisfied: pandas!=1.5.0,>=1.4 in /opt/anaconda3/lib/python3.11/site-packages (from mapclassify) (2.1.4)
# Requirement already satisfied: scikit-learn>=1.0 in /opt/anaconda3/lib/python3.11/site-packages (from mapclassify) (1.2.2)
# Requirement already satisfied: scipy>=1.8 in /opt/anaconda3/lib/python3.11/site-packages (from mapclassify) (1.11.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/anaconda3/lib/python3.11/site-packages (from pandas!=1.5.0,>=1.4->mapclassify) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /opt/anaconda3/lib/python3.11/site-packages (from pandas!=1.5.0,>=1.4->mapclassify) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /opt/anaconda3/lib/python3.11/site-packages (from pandas!=1.5.0,>=1.4->mapclassify) (2023.3)
# Requirement already satisfied: joblib>=1.1.1 in /opt/anaconda3/lib/python3.11/site-packages (from scikit-learn>=1.0->mapclassify) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/anaconda3/lib/python3.11/site-packages (from scikit-learn>=1.0->mapclassify) (2.2.0)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas!=1.5.0,>=1.4->mapclassify) (1.16.0)

# %% [markdown]
# **Transforming csv in geojson**

# %%
df = pd.read_csv('escolas_2023_coordenadas.csv')

# %%
df = df.replace({np.nan: None})

# %%
features = []
for _, row in df.iterrows():
    point = geojson.Point((row['Longitude'], row['Latitude']))
    properties = row.drop(['Longitude', 'Latitude']).to_dict()
    feature = geojson.Feature(geometry=point, properties=properties)
    features.append(feature)

# %%
feature_collection = geojson.FeatureCollection(features)

# %%
with open('escolas_2023_coordenadas.geojson', 'w') as f:
    geojson.dump(feature_collection, f)

# %% [markdown]
# **Plotting nap with geojson**

# %%
# Reading geojson file
data = gpd.read_file('escolas_2023_coordenadas.geojson')

# %%
data.columns
# Out:
# Index(['SG_UF', 'NO_ENTIDADE', 'IN_AGUA_POTAVEL', 'IN_COMP_PORTATIL_ALUNO',
#        'IN_INTERNET', 'TP_DEPENDENCIA', 'IN_EDUCACAO_INDIGENA', 'geometry'],
#       dtype='object')

# %%
# Sorting column for red dots appearing on top
data = data.sort_values(by='IN_INTERNET', ascending=False)

# %%
# Importing colors for ploting
from matplotlib.colors import ListedColormap

colors = {
    1: '#0000FF',
    0: '#FF0000'
}

cmap = ListedColormap([t[1] for t in sorted(colors.items())])

# %%
# Creating map
fig, ax = plt.subplots(figsize=(10, 8))  

# Plotting the contour of Brazil
br = gpd.read_file("BR_Pais_2022/BR_Pais_2022.shp")
br.boundary.plot(ax=ax, linewidth=0.5, edgecolor='black')

# Plotting indigenous lands
ti = gpd.read_file("https://raw.githubusercontent.com/bplmp/geopandas-ex-data/main/indigenous_area_legal_amazon.geojson")
ti.plot(ax=ax, color='grey')

# Plotting school data
data.plot(ax=ax, column='IN_INTERNET', cmap=cmap, legend=True, markersize=1, categorical=True)  # Adjusted marker size for better visibility

# Setting up legend
leg = ax.get_legend()
leg.set_bbox_to_anchor((1, 0))
leg.set_loc('lower right')
leg.set_title('School has internet?')
leg.get_texts()[0].set_text('No')
leg.get_texts()[1].set_text('Yes')
leg.set_frame_on(False)

# Removing axes
ax.set_axis_off()

# Adding title
ax.set_title('Map of Internet Availability in Schools')

# Adding source
ax.text(0.2, 0.0, 'Source: Censo Escolar 2023 (INEP)', ha='right', va='bottom', transform=ax.transAxes, fontsize=8, color='black')


plt.show()
